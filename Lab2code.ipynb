# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import scipy.signal as signal

# %%
flatBslist = np.genfromtxt('/Users/Ronnie/Astr329/lab2/imstat_flatBslist.txt')
flatBslist = flatBslist.T
flatBFslist = np.genfromtxt('/Users/Ronnie/Astr329/lab2/imstat_flatBFslist.txt')
flatBFslist = flatBFslist.T

# %%
signalBs=flatBslist[0]
noiseBs=flatBslist[1]
signalBFs=flatBFslist[0]
noiseBFs=flatBslist[1]

# %%
ex = np.array([140.,130.,120.,140.,100.,80.,40.,20.,10.,5.,2.5,1.25,0.6,0.3])

# %%
fig,ax=plt.subplots(2,1,figsize=(15,20))
plt.axes(ax[0])
ax[0].plot(ex,signalBs,'o',color='b',label='Bs')
ax[0].plot(ex,signalBFs,'o',color='r',label='BFs')
ax[0].set_xlim([0,150])
ax[0].set_ylim([0,70000])
ax[0].set_xlabel('exposure time [s]');ax[0].set_ylabel('signal (mean pixel value) [DU]');ax[0].legend(fontsize='small',loc=0)
ax[0].legend(fontsize='large')

plt.axes(ax[1])
ax[1].loglog(noiseBs,signalBs,color='b',label='Bs')
ax[1].loglog(noiseBFs,signalBFs,color='r',label='BFs')
#ax[1].set_xlim([0,150])
#ax[1].set_ylim([0,70000])
ax[1].set_xlabel('Signal[DU]');ax[1].set_ylabel('Noise (mean pixel value) [DU]');ax[1].legend(fontsize='small',loc=0)
ax[1].legend(fontsize='large')

# %%
y=data[0]
x=ex
N=len(y)

# %%
b = np.sum(x*y)-N*np.mean(x)*np.mean(y)
b = b/(np.sum(x**2)-N*np.mean(x)**2)
a = np.mean(y)-b*np.mean(x)
yhat=b*x+a

fig,ax=plt.subplots(1,1,figsize=(15,10))
ax.plot(x,y,'o')
ax.plot(x,yhat,'-',label='Fit: y=%1.4f+%1.4fx'%(a,b))
plt.legend(loc=0)
ax.set_xlabel('exposure time [s]');ax.set_ylabel('signal (mean pixel value) [DU]')
ax.set_xlim([0,150])
ax.set_ylim([0,70000])

# get the error bounds...
syx=np.sqrt(np.sum((y-yhat)**2)/(N-2))
import scipy.stats as stats

bdn,bup=stats.t.interval(0.95,df=N-2,scale=syx)
bb=np.array([bdn,bup])
bb=bb/np.sqrt(np.sum((x-np.mean(x))**2))
print 'Slope b is between %f and %f with 95%% probability'%(b+bb[0],b+bb[1])
xx=np.sort(x)
yhathigh=(b+bb[1])*(xx-np.mean(x))+np.mean(y)
yhatlow=(b+bb[0])*(xx-np.mean(x))+np.mean(y)
ax.fill_between(xx,yhathigh,yhatlow,alpha=0.4)
# Out:
# Slope b is between 403.557319 and 413.871537 with 95% probability

# %%
y=data[1]
x=data[0]
N=len(y)

b = np.sum(x*y)-N*np.mean(x)*np.mean(y)
b = b/(np.sum(x**2)-N*np.mean(x)**2)
a = np.mean(y)-b*np.mean(x)
yhat=b*x+a

fig,ax=plt.subplots(1,1,figsize=(15,10))
ax.loglog(x,y,'o')
ax.loglog(x,yhat,'-',label='Fit: y=%1.4f+%1.4fx'%(a,b))
plt.legend(loc=0)
ax.set_xlabel('exposure time [s]');ax.set_ylabel('signal (mean pixel value) [DU]')
#ax.set_xlim([0,150])
#ax.set_ylim([0,70000])

# get the error bounds...
syx=np.sqrt(np.sum((y-yhat)**2)/(N-2))
import scipy.stats as stats

bdn,bup=stats.t.interval(0.95,df=N-2,scale=syx)
bb=np.array([bdn,bup])
bb=bb/np.sqrt(np.sum((x-np.mean(x))**2))
print 'Slope b is between %f and %f with 95%% probability'%(b+bb[0],b+bb[1])
xx=np.sort(x)
yhathigh=(b+bb[1])*(xx-np.mean(x))+np.mean(y)
yhatlow=(b+bb[0])*(xx-np.mean(x))+np.mean(y)
ax.fill_between(xx,yhathigh,yhatlow,alpha=0.4)
# Out:
# Slope b is between 0.000394 and 0.003173 with 95% probability
